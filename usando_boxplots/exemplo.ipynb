# %%
import pandas as pd #importa a biblioteca pandas para análise de dados

DADOS = "dados/precos_fone_ouvido.csv" #cria variavel dados para o arquivo csv

df = pd.read_csv(DADOS) #le o arquivo csv

df #imprime o conteudo do arquivo na tela
# Out:
#     Price
# 0   189.0
# 1   195.0
# 2   199.0
# 3   189.0
# 4   197.0
# ..    ...
# 95  189.0
# 96  179.0
# 97  189.0
# 98  199.0
# 99  195.0
#
# [100 rows x 1 columns]

# %%
from auxiliar import box_hist_plot #importa a função box_hist_plot do arquivo auxiliar.py
box_hist_plot(df, 'Price') #chama a função box_hist_plot passando o dataframe e a coluna que deseja analisar
